# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
rng = np.random.RandomState(1)          
X = np.linspace(0, 6, 100).reshape(-1,1)  
y = np.sin(X).ravel() + np.sin(6 * X).ravel() + rng.normal(0, 0.1, X.shape[0])

# %%
rng.normal(0, 0.1, X.shape[0])
# Out:
# array([-0.04471286,  0.12245077,  0.04034916,  0.05935785, -0.10949118,
#         0.01693824,  0.07405565, -0.09537006, -0.02662185,  0.00326145,
#        -0.13731173,  0.03151594,  0.08461606, -0.08595159,  0.0350546 ,
#        -0.13122834, -0.00386955, -0.16157724,  0.11214177,  0.04089005,
#        -0.0024617 , -0.07751616,  0.12737559,  0.19671017, -0.18579819,
#         0.1236164 ,  0.16276508,  0.03380117, -0.1199268 ,  0.08633453,
#        -0.01809203, -0.06039206, -0.12300581,  0.05505375,  0.07928069,
#        -0.06235307,  0.05205763, -0.11443414,  0.0801861 ,  0.00465673,
#        -0.01865698, -0.01017459,  0.08688862,  0.07504116,  0.05294653,
#         0.01377012,  0.00778211,  0.06183803,  0.02324946,  0.06825514,
#        -0.03101168, -0.24348378,  0.10388246,  0.21869796,  0.04413644,
#        -0.01001552, -0.01364447, -0.01190542,  0.00174094, -0.11220187,
#        -0.05170945, -0.09970268,  0.02487992, -0.02966412,  0.04952113,
#        -0.01747032,  0.09863352,  0.02135339,  0.21906997, -0.18963609,
#        -0.06469167,  0.09014869,  0.25283257, -0.02486348,  0.0043669 ,
#        -0.02263142,  0.13314571, -0.02873079,  0.06800698, -0.03198016,
#        -0.12725588,  0.03135477,  0.05031848,  0.12932259, -0.0110447 ,
#        -0.06173621,  0.05627611,  0.02407371,  0.02806651, -0.00731127,
#         0.11603386,  0.03694927,  0.19046587,  0.11110567,  0.06590498,
#        -0.16274383,  0.06023193,  0.04202822,  0.08109517,  0.10444421])

# %%
X.shape[0]
# Out:
# 100

# %%
plt.scatter(X,y)

# %%
#训练回归模型
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),
                          n_estimators=300, random_state=rng)

regr_1.fit(X, y)
regr_2.fit(X, y)

#预测结果
y_1 = regr_1.predict(X)
y_2 = regr_2.predict(X)

# %%
y_1
# Out:
# array([ 0.8381376 ,  0.8381376 ,  0.8381376 ,  0.8381376 ,  0.8381376 ,
#         0.8381376 ,  0.8381376 ,  0.8381376 ,  0.8381376 ,  0.05854941,
#         0.05854941,  0.05854941,  0.05854941,  0.05854941,  0.05854941,
#         0.05854941,  0.05854941,  0.05854941,  1.72879521,  1.72879521,
#         1.72879521,  1.72879521,  1.72879521,  1.72879521,  1.72879521,
#         0.83474801,  0.83474801,  0.83474801,  0.83474801,  0.83474801,
#         0.83474801,  0.83474801,  0.83474801,  0.83474801,  0.83474801,
#         0.83474801,  0.83474801,  0.83474801,  0.83474801,  0.83474801,
#         0.83474801,  0.83474801,  0.83474801,  0.83474801,  0.17445009,
#        -0.42934405, -0.42934405, -0.42934405, -0.42934405, -0.42934405,
#        -0.42934405, -0.42934405, -0.42934405,  0.61016161,  0.61016161,
#         0.61016161,  0.61016161,  0.61016161,  0.61016161,  0.17908067,
#        -1.17131176, -1.17131176, -1.17131176, -1.17131176, -1.17131176,
#        -1.17131176, -1.17131176, -1.17131176, -1.17131176, -1.17131176,
#        -0.38282199, -0.38282199, -0.38282199, -0.38282199, -0.38282199,
#        -0.38282199, -0.38282199, -0.38282199, -0.38282199, -1.75010738,
#        -1.75010738, -1.75010738, -1.75010738, -1.75010738, -1.75010738,
#        -1.23306163, -1.23306163, -0.4201917 , -0.4201917 ,  0.05753552,
#         0.05753552,  0.05753552,  0.05753552,  0.05753552,  0.05753552,
#         0.05753552, -0.9360324 , -0.9360324 , -1.24093141, -1.24093141])

# %%
y_2
# Out:
# array([ 4.38061795e-01,  4.38061795e-01,  5.42766987e-01,  8.60372687e-01,
#         1.00151902e+00,  1.02639057e+00,  1.02639057e+00,  1.02142963e+00,
#         7.70493353e-01,  3.63110590e-01,  2.41014790e-01, -1.60148673e-01,
#        -1.60148673e-01, -1.60148673e-01, -7.43407630e-02,  3.50042497e-02,
#         5.26023206e-01,  6.68475495e-01,  1.25804247e+00,  1.36462060e+00,
#         1.77227673e+00,  1.78893792e+00,  1.78893792e+00,  1.78893792e+00,
#         1.63617122e+00,  1.20780605e+00,  9.17112033e-01,  5.56691158e-01,
#         4.53612853e-01,  2.61315464e-01,  2.21511653e-01,  2.21511653e-01,
#         2.90013140e-01,  4.51076693e-01,  5.60949069e-01,  9.61148243e-01,
#         1.14562127e+00,  1.43523328e+00,  1.55581138e+00,  1.55581138e+00,
#         1.35462675e+00,  1.09058535e+00,  9.08359491e-01,  8.03508232e-01,
#         1.74450085e-01, -2.11947190e-01, -2.85583620e-01, -4.59359323e-01,
#        -5.03604026e-01, -5.03604026e-01, -4.66056973e-01, -1.42573295e-01,
#        -6.46743306e-02,  3.05249750e-01,  4.10722473e-01,  5.89770794e-01,
#         6.27201686e-01,  6.27201686e-01,  2.86772736e-01,  1.79080667e-01,
#        -4.31496562e-01, -5.91493306e-01, -9.48487644e-01, -1.23586256e+00,
#        -1.41166611e+00, -1.41166611e+00, -1.41166611e+00, -1.39753511e+00,
#        -1.07262805e+00, -1.02944963e+00, -7.19716955e-01, -4.11790356e-01,
#        -2.03168396e-01, -1.59004026e-01, -1.59004026e-01, -2.72125665e-01,
#        -5.49773801e-01, -6.76528033e-01, -9.59750930e-01, -1.22302415e+00,
#        -1.54798028e+00, -1.70269845e+00, -1.70269845e+00, -1.70269845e+00,
#        -1.55258559e+00, -1.23306163e+00, -1.18257896e+00, -5.90662820e-01,
#        -3.87918131e-01,  9.83278507e-04,  1.26057236e-01,  1.26057236e-01,
#         1.23453535e-01, -1.09039445e-01, -2.70078989e-01, -4.81942011e-01,
#        -7.66227882e-01, -9.14894638e-01, -1.09603161e+00, -1.10143458e+00])

# %%
#绘制可视化图形
plt.figure()
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_1, c="g", label="DTR", linewidth=2)
plt.plot(X, y_2, c="r", label="ABR", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Boosted Decision Tree Regression")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_blobs
菊安酱CDA数据
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d5c09583127f> in <module>
#       3 from sklearn.svm import SVC
#       4 from sklearn.datasets import make_blobs
# ----> 5 菊安酱CDA数据
#
# NameError: name '菊安酱CDA数据' is not defined

# %%
print('{}:计算机{}的CPU占用率为{}%'.format('2017-09-30','python',10))
# Out:
# 2017-09-30:计算机python的CPU占用率为10%

# %%
print('{1}:计算机{0}的CPU占用率为{2}%.'.format('python','2017-09-30',10))
# Out:
# 2017-09-30:计算机python的CPU占用率为10%.

# %%
print('I am {arg[0]},I love {arg[1]}'.format(arg=arg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-252a6a25705e> in <module>
# ----> 1 print('I am {arg[0]},I love {arg[1]}'.format(arg=arg))
#
# NameError: name 'arg' is not defined

# %%
print('%s的年龄是%d'%('小哥哥',20))
# Out:
# 小哥哥的年龄是20

# %%
'{0}的年龄是{1}'.format('小哥哥',20)
# Out:
# '小哥哥的年龄是20'

# %%
'{0}的年龄是{1}'.format('小哥哥',20)
# Out:
# '小哥哥的年龄是20'

# %%
'{name}的年龄是{age}'.format(age=20,name='小哥哥')
# Out:
# '小哥哥的年龄是20'

# %%
list5=[[1,2,3],[4,5,6],[7,8,9]]

# %%
list5[0][0]
# Out:
# 1

# %%
list5[-1]
# Out:
# [7, 8, 9]

# %%
list5[::-1]
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %% [markdown]
# ## 列表常用方法

# %%
L=[1,2,3,4,5]

# %%
L.index(5)
# Out:
# 4

# %%
L.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-68f973475156> in <module>
# ----> 1 L.index()
#
# TypeError: index() takes at least 1 argument (0 given)

# %%
L.index(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-725d9ccbe56a> in <module>
# ----> 1 L.index(6)
#
# ValueError: 6 is not in list

# %%
L.count(6)
# Out:
# 0

# %%
L.sort()

# %%
L
# Out:
# [1, 2, 3, 4, 5]

# %%
L1=[2,4,6,1,3,5]

# %%
L1.sort()

# %%
L1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L1.sort(reverse=True)

# %%
L1
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
 L1=[2,4,6,1,3,5]

# %%
L1.reverse()

# %%
L1
# Out:
# [5, 3, 1, 6, 4, 2]

# %%
L
# Out:
# [1, 2, 3, 4, 5]

# %%
L.append(6)

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L.append(6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-c8dd4d5774c8> in <module>
# ----> 1 L.append(6,7)
#
# TypeError: append() takes exactly one argument (2 given)

# %%
L.append([6,7])

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, [6, 7]]

# %%
L.extend(6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-4555c3542c03> in <module>
# ----> 1 L.extend(6)
#
# TypeError: 'int' object is not iterable

# %%
L.extend([1,2,3])

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, [6, 7], 1, 2, 3]

# %%
L.insert(4,11)

# %%
L
# Out:
# [1, 2, 3, 4, 11, 5, 6, [6, 7], 1, 2, 3]

# %%
L.insert(2,[2,3])

# %%
L
# Out:
# [1, 2, [2, 3], 3, 4, 11, 5, 6, [6, 7], 1, 2, 3]

# %%
del L

# %%
L
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-a9dfae9159c1> in <module>
# ----> 1 L
#
# NameError: name 'L' is not defined

# %%
L1.clear()

# %%
L1
# Out:
# []

# %%
L=[1,2,3,4,5]

# %%
L[:]
# Out:
# [1, 2, 3, 4, 5]

# %%
del L[:]

# %%
L
# Out:
# []

# %%
L
# Out:
# []

# %%
L.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-8d23c05c5ba5> in <module>
# ----> 1 L.remove()
#
# TypeError: remove() takes exactly one argument (0 given)

# %%
L=[1,2,3,4,5]

# %%
L.remove(4)

# %%
L
# Out:
# [1, 2, 3, 5]

# %%
L
# Out:
# [1, 2, 3, 5]

# %%
L.pop()
# Out:
# 5

# %%
L
# Out:
# [1, 2, 3]

# %%
L.pop(0)
# Out:
# 1

# %%
L
# Out:
# [2, 3]

# %%
L
# Out:
# [2, 3]

# %%
L.pop(0)
# Out:
# 2

# %%
L
# Out:
# [3]

# %%
'123'+'11'
# Out:
# '12311'

# %%
[1,2,3]+[2,3,4]
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
'12'+[1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-333d368e3820> in <module>
# ----> 1 '12'+[1,2]
#
# TypeError: can only concatenate str (not "list") to str

# %%
'123'*3
# Out:
# '123123123'

# %%
[1,2,3]+[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
'Hello,'+'World!'
# Out:
# 'Hello,World!'

# %%
a=['a','b','c']

# %%
a*3
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']

# %%
L
# Out:
# [3]

# %%
L=[1,2,3,4,5]

# %%
2 in L
# Out:
# True

# %%
8  in L
# Out:
# False

# %%
X='abcd'

# %%
'a' in X
# Out:
# True

# %%
'e' in X
# Out:
# False

# %%
users=['Evan','John','Sherry']

# %%
input('Enter your user name:') in users
# Out:
# Enter your user name:John
# True

# %%
a=[1,2,3]

# %%
b=a

# %%
b
# Out:
# [1, 2, 3]

# %%
b[1]=4

# %%
b
# Out:
# [1, 4, 3]

# %%
a
# Out:
# [1, 4, 3]

# %%
a=[1,2,3]

# %%
b=a.copy()

# %%
b
# Out:
# [1, 2, 3]

# %%
b[1]=4

# %%
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 4, 3]

# %%
a=[1,2,3]

# %%
b=a[:]

# %%
b
# Out:
# [1, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
L=[1,2,3,4,5]

# %%
type(input('请输入一个数字：'))
# Out:
# 请输入一个数字：3
# str

# %%
L
# Out:
# [1, 2, 3, 4, 5]

# %%
L1=L[:]
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L=100
L
# Out:
# 100

# %%
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L2=L1
L2[0]=4
L1
# Out:
# [4, 2, 3, 4, 5]

# %%
L2
# Out:
# [4, 2, 3, 4, 5]

# %%
import copy

# %%
L=[1,2,3,4,5]

# %%
L1=L[:]
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L=100
L
# Out:
# 100

# %%
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L2=L1
L2[0]=4
L1
# Out:
# [4, 2, 3, 4, 5]

# %%
L2
# Out:
# [4, 2, 3, 4, 5]

# %%
a=[1,2,3]

# %%
b=a
b[1]=4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 4, 3]

# %%
a=[1,2,3]
b=a.copy()
b[1]=4
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 4, 3]

# %%
a=[1,2,3]

# %%
b=a[:]

# %%
b
# Out:
# [1, 2, 3]

# %%
del b

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-89e6c98d9288> in <module>
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
a
# Out:
# [1, 2, 3]

# %%
del a[:]

# %%
a
# Out:
# []

# %%
list1=[1,2,3]

# %%
list1.clear()
list1
# Out:
# []

# %%
list1=[1,2,3]

# %%
list1[:]=[]

# %%
list1
# Out:
# []

# %%
a=(1,2,3)

# %%
type(a)
# Out:
# tuple

# %%
aTuple=(1,2,3)

# %%
aTuple
# Out:
# (1, 2, 3)

# %%
tp=(1)
tp
# Out:
# 1

# %%
tp1=(1,)

# %%
tp1
# Out:
# (1,)

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
t=(1,2,3)
t
# Out:
# (1, 2, 3)

# %%
t[1]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-791b664e8e14> in <module>
# ----> 1 t[1]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
L=[1]
L
# Out:
# [1]

# %%
t=(1)
t
# Out:
# 1

# %%
t=(1,)
t
# Out:
# (1,)

# %%
 len(t)
# Out:
# 1

# %%
t1=('A','B',['X','Y'])
t1
# Out:
# ('A', 'B', ['X', 'Y'])

# %%
t1[0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-249ba45634f4> in <module>
# ----> 1 t1[0]='a'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1[2]=['x','y']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-aa4c8377c3e2> in <module>
# ----> 1 t1[2]=['x','y']
#
# TypeError: 'tuple' object does not support item assignment

# %%
 t1[2][1]='y'

# %%
t1
# Out:
# ('A', 'B', ['X', 'y'])

# %%
del t1

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-5db19043943a> in <module>
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
t1=('A','B',['X','Y'])

# %%
t1.remove('A')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-194-c344f4549161> in <module>
# ----> 1 t1.remove('A')
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t1.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-195-36342d64d702> in <module>
# ----> 1 t1.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
t1.append(('1',))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-78cd45676f06> in <module>
# ----> 1 t1.append(('1',))
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
b = ('x', 'y', 1, 'x', 2, 'x')
b.index('x',4)
# Out:
# 5

# %%
b.count('x')
# Out:
# 3

# %%
d={2,4,5,3,1,1,1,3}
d
# Out:
# {1, 2, 3, 4, 5}

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-123a9cc6df61> in <module>
# ----> 1 d[0]
#
# TypeError: 'set' object is not subscriptable

# %%
d1=set([1,2,3,3])
d1
# Out:
# {1, 2, 3}

# %%
set([])
# Out:
# set()

# %%
set(())
# Out:
# set()

# %%
type(set({}))
# Out:
# set

# %%
s={}
type(s)
# Out:
# dict

# %%
set('abc')
# Out:
# {'a', 'b', 'c'}

# %%
set(['a','b','c'])
# Out:
# {'a', 'b', 'c'}

# %%
set(('a','b','c'))
# Out:
# {'a', 'b', 'c'}

# %%
set(())
# Out:
# set()

# %%
set([])
# Out:
# set()

# %%
set({})
# Out:
# set()

# %%
s={1,2,3,4,5}
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(1)
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(6)
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.update('1243')
s
# Out:
# {1, '1', 2, '2', 3, '3', 4, '4', 5, 6}

# %%
s.update([7,8,9])
s
# Out:
# {1, '1', 2, '2', 3, '3', 4, '4', 5, 6, 7, 8, 9}

# %%
s.remove('1')

# %%
s
# Out:
# {1, 2, '2', 3, '3', 4, '4', 5, 6, 7, 8, 9}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {'2', 3, '3', 4, '4', 5, 6, 7, 8, 9}

# %%
s.remove(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-228-23b5f1bb77c8> in <module>
# ----> 1 s.remove(10)
#
# KeyError: 10

# %%
s.discard(9)
s
# Out:
# {'2', 3, '3', 4, '4', 5, 6, 7, 8}

# %%
s.discard(10)
s
# Out:
# {'2', 3, '3', 4, '4', 5, 6, 7, 8}

# %%
s=set(('Google','Facebook','Alibaba','Amazon'))
s
# Out:
# {'Alibaba', 'Amazon', 'Facebook', 'Google'}

# %%
s.add('Baidu')
s
# Out:
# {'Alibaba', 'Amazon', 'Baidu', 'Facebook', 'Google'}

# %%
s.update({1,2,3})
s
# Out:
# {1, 2, 3, 'Alibaba', 'Amazon', 'Baidu', 'Facebook', 'Google'}

# %%
s.update([1,2],[3,4])
s
# Out:
# {1, 2, 3, 4, 'Alibaba', 'Amazon', 'Baidu', 'Facebook', 'Google'}

# %%
s.remove('Amazon')
s
# Out:
# {1, 2, 3, 4, 'Alibaba', 'Baidu', 'Facebook', 'Google'}

# %%
s.remove(9)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-238-d6996fc5cb16> in <module>
# ----> 1 s.remove(9)
#
# KeyError: 9

# %%
s.discard(4)

# %%
s
# Out:
# {1, 2, 3, 'Alibaba', 'Baidu', 'Facebook', 'Google'}

# %%
s=set(('Google', 'Facebook','Alibaba','Amazon'))

# %%
x=s.pop()

# %%
x
# Out:
# 'Facebook'

# %%
s=set(('Google', 'Facebook','Alibaba','Amazon'))
s.pop()
s
# Out:
# {'Alibaba', 'Amazon', 'Google'}

# %%
s.pop()
# Out:
# 'Google'

# %%
s
# Out:
# {'Alibaba', 'Amazon'}

# %%
s=set(('Google','Facebook','Alibaba','Amazon'))

# %%
s
# Out:
# {'Alibaba', 'Amazon', 'Facebook', 'Google'}

# %%
len(s)
# Out:
# 4

# %%
s.clear()
s
# Out:
# set()

# %%
s={'2','3',4,5,6,7,8}
s
# Out:
# {'2', '3', 4, 5, 6, 7, 8}

# %%
'2'in s
# Out:
# True

# %%
s=set(('Google','Facebook','Alibaba','Amazon'))

# %%
s
# Out:
# {'Alibaba', 'Amazon', 'Facebook', 'Google'}

# %%
'Facebook' in s
# Out:
# True

# %%
'Baidu' in s
# Out:
# False

# %% [markdown]
# ### 集合运算

# %%
s1={1,2,3,4}
s2={3,4,5,6}

# %%
# 交集
s1&s2
# Out:
# {3, 4}

# %%
# 并集
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# 差集
s1-s2
# Out:
# {1, 2}

# %%
s2-s1
# Out:
# {5, 6}

# %%
# 对称差
s1^s2
# Out:
# {1, 2, 5, 6}

# %%
# 子集
s1<=s2
# Out:
# False

# %%
s3={1,2}
s3<=s1
# Out:
# True

# %%
# 超集
s1>=s3
# Out:
# True

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.update(s2)
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1|=s2

# %%
s2|=s1

# %%
s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
x={'apple','banana','lemon'}
y={'Google','Facebook','apple'}

# %%
z=x.intersection(y)
z
# Out:
# {'apple'}

# %%
x={'a','b','c'}
Y={'c','d','e'}
z={'f','g','c'}

# %%
re=x.intersection(Y,z)
re
# Out:
# {'c'}

# %%
x={'apple','banana','lemon'}
y={'Google','Facebook','apple'}

# %%
z=x.union(y)
z
# Out:
# {'Facebook', 'Google', 'apple', 'banana', 'lemon'}

# %%
x={'a','b','c'}
y={'c','d','e'}
z={'f','g','c'}

# %% [raw]
# re=x.union(y,z)
# re

# %%
re
# Out:
# {'c'}

# %%
a=[1,3,5]
b=[1,2,3]

# %%
set(a)|set(b)
# Out:
# {1, 2, 3, 5}

# %%
set(a).union(b)
# Out:
# {1, 2, 3, 5}

# %%
set(a)&set(b)
# Out:
# {1, 3}

# %%
set(a).intersection(b)
# Out:
# {1, 3}

# %%
set(a)-set(b)
# Out:
# {5}

# %%
set(a).difference(b)
# Out:
# {5}

# %%
set(a)^set(b)
# Out:
# {2, 5}

# %%
set(a).symmetric_difference(b)
# Out:
# {2, 5}

# %%
x = {'apple','banana','lemon'}
y = {'Google','Facebook','apple'}
z = x.difference(y)

# %%
z
# Out:
# {'banana', 'lemon'}

# %%
x = {'apple','banana','lemon'}
y = {'Google','Facebook','apple'}
z = x.symmetric_difference(y)
print(z)
# Out:
# {'lemon', 'Facebook', 'banana', 'Google'}

# %%
x={'a','b','c'}
y={'f','e','d','c','b','a'}
z=x.issubset(y)
z
# Out:
# True

# %%
x={'a','b','c'}
y={'f','e','d','c','b'}

# %%
z=x.issubset(y)
z
# Out:
# False

# %%
x = {'apple','banana','lemon'}
y = {'Google','Facebook','apple'}
x.update(y)
print(x)
# Out:
# {'Facebook', 'banana', 'apple', 'lemon', 'Google'}

# %%
x={'apple','banana','lemon'}
y={'Google','Facebook','Amazon'}

# %%
z=x.isdisjoint(y)
z
# Out:
# True

# %%
x={'apple','banana','lemon'}
y={'Google','Facebook','apple'}

# %%
z=x.isdisjoint(y)
z
# Out:
# False

# %%
d=dict(a=1,b=2)
d
# Out:
# {'a': 1, 'b': 2}

# %%
d={'Name':'Evan','Age':20,'Class':'First'}

# %%
type(d)
# Out:
# dict

# %%
d['Name']
# Out:
# 'Evan'

# %%
d['Age']
# Out:
# 20

# %%
d['Sherry']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-309-6868f1547eed> in <module>
# ----> 1 d['Sherry']
#
# KeyError: 'Sherry'

# %%
d['Age']=22

# %%
d
# Out:
# {'Name': 'Evan', 'Age': 22, 'Class': 'First'}

# %%
d['School']='cda数据分析研究院'

# %%
d
# Out:
# {'Name': 'Evan', 'Age': 22, 'Class': 'First', 'School': 'cda数据分析研究院'}

# %%
del d['Name']
d
# Out:
# {'Age': 22, 'Class': 'First', 'School': 'cda数据分析研究院'}

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
del  d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-318-e983f374794d> in <module>
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
d={['Name']:'Evan','Age':20,'Name':'Joe'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-321-69b3dc069905> in <module>
# ----> 1 d={['Name']:'Evan','Age':20,'Name':'Joe'}
#
# TypeError: unhashable type: 'list'

# %%
d['Name']
# Out:
# 'Joe'

# %%
d={['Name']:'Evan','Age':20,'Name':'Joe'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-324-69b3dc069905> in <module>
# ----> 1 d={['Name']:'Evan','Age':20,'Name':'Joe'}
#
# TypeError: unhashable type: 'list'

# %%
d
# Out:
# {'Name': 'Joe', 'Age': 20}

# %%
d={'Name':'Evan','Age':20,'Class':'First'}

# %%
len(d)
# Out:
# 3

# %%
str(d)
# Out:
# "{'Name': 'Evan', 'Age': 20, 'Class': 'First'}"

# %%
d.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
d.values()
# Out:
# dict_values(['Evan', 20, 'First'])

# %%
d.items()
# Out:
# dict_items([('Name', 'Evan'), ('Age', 20), ('Class', 'First')])

# %%
d.get('Name')
# Out:
# 'Evan'

# %%
d
# Out:
# {'Name': 'Evan', 'Age': 20, 'Class': 'First'}

# %%
d1={'Name':'Evan','Age':27,'Height':188}

# %%
d.update(d1)
d
# Out:
# {'Name': 'Evan', 'Age': 27, 'Class': 'First', 'Height': 188}

# %%
d1
# Out:
# {'Name': 'Evan', 'Age': 27, 'Height': 188}

# %%
d1.setdefault('f')

# %%
d1
# Out:
# {'Name': 'Evan', 'Age': 27, 'Height': 188, 'f': None}

# %%
d1.setdefault('e',5)
# Out:
# 5

# %%
d1
# Out:
# {'Name': 'Evan', 'Age': 27, 'Height': 188, 'f': None, 'e': 5}

# %% [markdown]
# ### if条件判断

# %%
age=20

# %%
if age>18:
    print('你的年龄是：',age)
# Out:
# 你的年龄是： 20

# %%
if age>30:
    print('你的年龄是：',age)
else:
    print('你的年龄是：',age)
# Out:
# 你的年龄是： 20

# %%
age=3
if age>=18:
    print('你还是个成年人')
elif age>=6:
    print('要努力读书')  
    
else:
    print('你还是个孩子')
# Out:
# 你还是个孩子

# %%
a='顺序结构'
print(a)
# Out:
# 顺序结构

# %%
a
# Out:
# '顺序结构'

# %%
age=int(input('请输入您的年龄：'))
if age>=18:
    print('您已成年，可以上网吧！')
else:
    print('您未成年，不可以上网吧！！')
# Out:
# 请输入您的年龄：12
# 您未成年，不可以上网吧！！

# %%
age=input('请输入一个年龄：')
# Out:
# 请输入一个年龄：12

# %%
type(age)
# Out:
# str

# %%
height=float(input('请输入身高：'))
weight=float(input('请输入体重：'))
a=weight/(height**2) 
if a>=32:
    print('严重肥胖')
elif a>=28:
    print('肥胖')
elif a>=25:
    print('过重')
elif a>=18.5:
    print('正常')
else:
    print('过轻')
# Out:
# 请输入身高：1.60
# 请输入体重：85
# 严重肥胖

# %%
a
# Out:
# 41.52249134948097

# %%
chepiao=0
knife=10
if chepiao==1:
    if knife<10:
        print('通过安检')
        print('终于见到那个她了')
    else:
        print('没有通过安检')
        print('刀子的长度超过规定')
else:
    print('没有车票')
    print('只有下次再见了')
# Out:
# 没有车票
# 只有下次再见了

# %%
yuer=float(input('请输入公交卡的余额：'))

if yuer>=2:
    zuowei=float(input('请输入空座位数：'))
    if zuowei>0:
        print('可以坐下')
    else:
        print('没有空座')
else:
    print('余额不足')
# Out:
# 请输入公交卡的余额：5
# 请输入空座位数：0
# 没有空座

# %%
nian=int(input('请输入年份：'))
if nian%400==0:
    print('该年为世纪闰年')
elif nian%4==0 and nian%100 !=0:
    print('该年是普通闰年')
    
else:
    print('该年不是闰年')
# Out:
# 请输入年份：1999
# 该年不是闰年

# %%
help(isdigit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5789bfcfdad3> in <module>
# ----> 1 help(isdigit)
#
# NameError: name 'isdigit' is not defined

# %%
year=input('请输入一个年份：')
if year.isdigit() and len(year)==4:
    year=int(year)
    if year%400==0 or (year%4==0 and year%100 !=0):
        print('您输入的%s年为闰年'%year)
    else:
        print('您输入的%s年为平年'%year)
else:
    print('您输入的年份有误，请重新输入！')
# Out:
# 请输入一个年份：2009
# 您输入的2009年为平年

# %%
print('您输入的%s年为闰年'%2019)
# Out:
# 您输入的2019年为闰年

# %%
i=0
while i<100:
    print('第',i,'次我错了')
    i+=1
# Out:
# 第 0 次我错了
# 第 1 次我错了
# 第 2 次我错了
# 第 3 次我错了
# 第 4 次我错了
# 第 5 次我错了
# 第 6 次我错了
# 第 7 次我错了
# 第 8 次我错了
# 第 9 次我错了
# 第 10 次我错了
# 第 11 次我错了
# 第 12 次我错了
# 第 13 次我错了
# 第 14 次我错了
# 第 15 次我错了
# 第 16 次我错了
# 第 17 次我错了
# 第 18 次我错了
# 第 19 次我错了
# 第 20 次我错了
# 第 21 次我错了
# 第 22 次我错了
# 第 23 次我错了
# 第 24 次我错了
# 第 25 次我错了
# 第 26 次我错了
# 第 27 次我错了
# 第 28 次我错了
# 第 29 次我错了
# 第 30 次我错了
# 第 31 次我错了
# 第 32 次我错了
# 第 33 次我错了
# 第 34 次我错了
# 第 35 次我错了
# 第 36 次我错了
# 第 37 次我错了
# 第 38 次我错了
# 第 39 次我错了
# 第 40 次我错了
# 第 41 次我错了
# 第 42 次我错了
# 第 43 次我错了
# 第 44 次我错了
# 第 45 次我错了
# 第 46 次我错了
# 第 47 次我错了
# 第 48 次我错了
# 第 49 次我错了
# 第 50 次我错了
# 第 51 次我错了
# 第 52 次我错了
# 第 53 次我错了
# 第 54 次我错了
# 第 55 次我错了
# 第 56 次我错了
# 第 57 次我错了
# 第 58 次我错了
# 第 59 次我错了
# 第 60 次我错了
# 第 61 次我错了
# 第 62 次我错了
# 第 63 次我错了
# 第 64 次我错了
# 第 65 次我错了
# 第 66 次我错了
# 第 67 次我错了
# 第 68 次我错了
# 第 69 次我错了
# 第 70 次我错了
# 第 71 次我错了
# 第 72 次我错了
# 第 73 次我错了
# 第 74 次我错了
# 第 75 次我错了
# 第 76 次我错了
# 第 77 次我错了
# 第 78 次我错了
# 第 79 次我错了
# 第 80 次我错了
# 第 81 次我错了
# 第 82 次我错了
# 第 83 次我错了
# 第 84 次我错了
# 第 85 次我错了
# 第 86 次我错了
# 第 87 次我错了
# 第 88 次我错了
# 第 89 次我错了
# 第 90 次我错了
# 第 91 次我错了
# 第 92 次我错了
# 第 93 次我错了
# 第 94 次我错了
# 第 95 次我错了
# 第 96 次我错了
# 第 97 次我错了
# 第 98 次我错了
# 第 99 次我错了

# %%
i=1
sum=0
while i<101:
    sum=sum+i
    i+=1
print(sum)
# Out:
# 5050

# %%
sum
# Out:
# 5050
